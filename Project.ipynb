# %% [markdown]
# <div style="font-family: 'Times New Roman'; font-weight: bold; font-size: 2em; text-align: center;">
#     Analisis Pengaruh Teknik Preprocessing terhadap Klasifikasi Tekstur Tanah Black Soil dan Red Soil Menggunakan Fitur GLCM dan Algoritma Random Forest.
# </div>
